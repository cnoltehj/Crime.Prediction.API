# %%
print('1')
total = 200
print('total =', total)

train_size = int((total) * 0.7)
val_size = int((total) * 0.15)
test_size = (total) - train_size - val_size
test = 100 - 70 - 15

print('train_size = ', train_size)
print('val_size=',val_size)
print('test_size=',test_size)
print('test =', test)
print('===============================')

train_size_02 = int(0.7 * (total))
val_test_size_02 = int(0.15 * (total))
val_size_02 = int(0.15 * (total))

print('train_size_02=', train_size_02), 
print('val_test_size_02=', val_test_size_02)
print('val_size_02=',val_size_02)
# Out:
# 1
# total = 200
# train_size =  140
# val_size= 30
# test_size= 30
# test = 15
# ...
# train_size_02= 140
# val_test_size_02= 30
# val_size_02= 30
